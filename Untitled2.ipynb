# %% [markdown]
# <a href="https://colab.research.google.com/github/Nafis061/Nafis.github.io/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(1-10):
  for j in range(11-20):
    print("i*j")

# %%
a=4
b=3
print(a+b)
# Out:
# 7

# %%
number=int(input("Enter the number that you got: "))
if number >= 80:
 print("you have done an excellent job")
else:
  print("you have to work hard to meet the desired goal")
# Out:
# Enter the number that you got: 60
# you have to work hard to meet the desired goal
